# %%
import pandas as pd

df = pd.read_csv("orders.csv")


df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv("orders.csv")
#       6 df
#
# File c:\Users\saini\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %% [markdown]
# 1️⃣ Display first & last 5 rows

# %% [markdown]
# 2️⃣ Number of rows & columns

# %% [markdown]
# 3️⃣ Column names

# %% [markdown]
# 4️⃣ Data types

# %% [markdown]
# 5️⃣ Select Customer, Product, Price

# %% [markdown]
# 6️⃣ Orders from New York

# %% [markdown]
# 7️⃣ Orders where Quantity > 2

# %% [markdown]
# 8️⃣ Sort by Price descending

# %% [markdown]
# 9️⃣ Unique cities

# %% [markdown]
# 🔟 Count orders per city

# %% [markdown]
# ## 🟡 Intermediate Questions
# 1️⃣ Total amount per order (Quantity × Price)

# %% [markdown]
# 2️⃣ Total sales per category

# %% [markdown]
# 3️⃣ Average order value per city

# %% [markdown]
# 4️⃣ Orders paid using UPI

# %% [markdown]
# 5️⃣ Convert OrderDate to datetime

# %% [markdown]
# 6️⃣ Orders after March 2022

# %% [markdown]
# 7️⃣ Most expensive product

# %% [markdown]
# 8️⃣ Number of products sold per category

# %% [markdown]
# 9️⃣ Customers with more than one order

# %% [markdown]
# 🔟 City with highest total sales

# %% [markdown]
# ## 🔴 Advanced Questions + Solutions
# 1️⃣ Rank orders by TotalAmount within each city

# %% [markdown]
# 2️⃣ Top 2 highest sales orders per city

# %% [markdown]
# 3️⃣ Correlation between Quantity and TotalAmount

# %% [markdown]
# 4️⃣ Pivot table: Average sales by City & Category

# %% [markdown]
# 5️⃣ Orders above category average sale

# %% [markdown]
# 6️⃣ Monthly sales trend

# %% [markdown]
# 7️⃣ Detect duplicate customers

# %%
8️⃣ Normalize TotalAmount (min-max)

# %% [markdown]
# 9️⃣ Detect outliers using IQR

# %% [markdown]
# 🔟 Export Electronics orders to CSV

# %% [markdown]
# # 🧠 What you practiced here
#
# ✅ Filtering
#
# ✅ GroupBy & Aggregations
#
# ✅ Ranking
#
# ✅ Pivot tables
#
# ✅ Datetime operations
#
# ✅ Correlation
#
# ✅ Normalization
#
# ✅ Outlier detection
#
# ✅ File export
